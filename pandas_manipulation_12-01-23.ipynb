# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample.csv')

# %%
df
# Out:
#    ID    Name               Email
# 0   1   Rahim   rahim@example.com
# 1   2   Karim   karim@example.com
# 2   3  Ayesha  ayesha@example.com

# %%
df=pd.read_csv('/content/large_dataset.csv')

# %%
df
# Out:
#     User_ID     Name               Email      Phone        City  Age    Status
# 0         1   User_1   user1@example.com  170000001       Dhaka   19    Active
# 1         2   User_2   user2@example.com  170000002  Chattogram   20  Inactive
# 2         3   User_3   user3@example.com  170000003      Khulna   21    Active
# 3         4   User_4   user4@example.com  170000004    Rajshahi   22  Inactive
# 4         5   User_5   user5@example.com  170000005      Sylhet   23    Active
# 5         6   User_6   user6@example.com  170000006       Dhaka   24  Inactive
# 6         7   User_7   user7@example.com  170000007  Chattogram   25    Active
# 7         8   User_8   user8@example.com  170000008      Khulna   26  Inactive
# 8         9   User_9   user9@example.com  170000009    Rajshahi   27    Active
# 9        10  User_10  user10@example.com  170000010      Sylhet   28  Inactive
# 10       11  User_11  user11@example.com  170000011       Dhaka   29    Active
# ...

# %%
df.head(20)
# Out:
#     User_ID     Name               Email      Phone        City  Age    Status
# 0         1   User_1   user1@example.com  170000001       Dhaka   19    Active
# 1         2   User_2   user2@example.com  170000002  Chattogram   20  Inactive
# 2         3   User_3   user3@example.com  170000003      Khulna   21    Active
# 3         4   User_4   user4@example.com  170000004    Rajshahi   22  Inactive
# 4         5   User_5   user5@example.com  170000005      Sylhet   23    Active
# 5         6   User_6   user6@example.com  170000006       Dhaka   24  Inactive
# 6         7   User_7   user7@example.com  170000007  Chattogram   25    Active
# 7         8   User_8   user8@example.com  170000008      Khulna   26  Inactive
# 8         9   User_9   user9@example.com  170000009    Rajshahi   27    Active
# 9        10  User_10  user10@example.com  170000010      Sylhet   28  Inactive
# 10       11  User_11  user11@example.com  170000011       Dhaka   29    Active
# ...

# %%
df.tail()
# Out:
#     User_ID     Name               Email      Phone        City  Age    Status
# 45       46  User_46  user46@example.com  170000046       Dhaka   34  Inactive
# 46       47  User_47  user47@example.com  170000047  Chattogram   35    Active
# 47       48  User_48  user48@example.com  170000048      Khulna   36  Inactive
# 48       49  User_49  user49@example.com  170000049    Rajshahi   37    Active
# 49       50  User_50  user50@example.com  170000050      Sylhet   38  Inactive

# %%
df[['Name','Phone','Age']]
# Out:
#        Name      Phone  Age
# 0    User_1  170000001   19
# 1    User_2  170000002   20
# 2    User_3  170000003   21
# 3    User_4  170000004   22
# 4    User_5  170000005   23
# 5    User_6  170000006   24
# 6    User_7  170000007   25
# 7    User_8  170000008   26
# 8    User_9  170000009   27
# 9   User_10  170000010   28
# 10  User_11  170000011   29
# 11  User_12  170000012   30
# 12  User_13  170000013   31
# 13  User_14  170000014   32
# 14  User_15  170000015   33
# 15  User_16  170000016   34
# 16  User_17  170000017   35
# 17  User_18  170000018   36
# 18  User_19  170000019   37
# 19  User_20  170000020   38
# 20  User_21  170000021   39
# 21  User_22  170000022   40
# 22  User_23  170000023   41
# 23  User_24  170000024   42
# 24  User_25  170000025   43
# 25  User_26  170000026   44
# 26  User_27  170000027   45
# 27  User_28  170000028   46
# 28  User_29  170000029   47
# 29  User_30  170000030   18
# 30  User_31  170000031   19
# 31  User_32  170000032   20
# ...

# %%
df[df['Age']>35]
# Out:
#     User_ID     Name               Email      Phone        City  Age    Status
# 17       18  User_18  user18@example.com  170000018      Khulna   36  Inactive
# 18       19  User_19  user19@example.com  170000019    Rajshahi   37    Active
# 19       20  User_20  user20@example.com  170000020      Sylhet   38  Inactive
# 20       21  User_21  user21@example.com  170000021       Dhaka   39    Active
# 21       22  User_22  user22@example.com  170000022  Chattogram   40  Inactive
# 22       23  User_23  user23@example.com  170000023      Khulna   41    Active
# 23       24  User_24  user24@example.com  170000024    Rajshahi   42  Inactive
# 24       25  User_25  user25@example.com  170000025      Sylhet   43    Active
# 25       26  User_26  user26@example.com  170000026       Dhaka   44  Inactive
# 26       27  User_27  user27@example.com  170000027  Chattogram   45    Active
# 27       28  User_28  user28@example.com  170000028      Khulna   46  Inactive
# ...

# %%
df[(df['Age']>35)&(df['Status']=='Active')]
# Out:
#     User_ID     Name               Email      Phone        City  Age  Status
# 18       19  User_19  user19@example.com  170000019    Rajshahi   37  Active
# 20       21  User_21  user21@example.com  170000021       Dhaka   39  Active
# 22       23  User_23  user23@example.com  170000023      Khulna   41  Active
# 24       25  User_25  user25@example.com  170000025      Sylhet   43  Active
# 26       27  User_27  user27@example.com  170000027  Chattogram   45  Active
# 28       29  User_29  user29@example.com  170000029    Rajshahi   47  Active
# 48       49  User_49  user49@example.com  170000049    Rajshahi   37  Active

# %%
df.loc[9:14,['User_ID','Email']]
# Out:
#     User_ID               Email
# 9        10  user10@example.com
# 10       11  user11@example.com
# 11       12  user12@example.com
# 12       13  user13@example.com
# 13       14  user14@example.com
# 14       15  user15@example.com

# %%
df.query('Age>30 and Status=="Active"')
# Out:
#     User_ID     Name               Email      Phone        City  Age  Status
# 12       13  User_13  user13@example.com  170000013      Khulna   31  Active
# 14       15  User_15  user15@example.com  170000015      Sylhet   33  Active
# 16       17  User_17  user17@example.com  170000017  Chattogram   35  Active
# 18       19  User_19  user19@example.com  170000019    Rajshahi   37  Active
# 20       21  User_21  user21@example.com  170000021       Dhaka   39  Active
# 22       23  User_23  user23@example.com  170000023      Khulna   41  Active
# 24       25  User_25  user25@example.com  170000025      Sylhet   43  Active
# 26       27  User_27  user27@example.com  170000027  Chattogram   45  Active
# 28       29  User_29  user29@example.com  170000029    Rajshahi   47  Active
# 42       43  User_43  user43@example.com  170000043      Khulna   31  Active
# 44       45  User_45  user45@example.com  170000045      Sylhet   33  Active
# ...

# %%
df.groupby('Status')['Age'].mean()
# Out:
# Status
# Active      31.0
# Inactive    30.8
# Name: Age, dtype: float64

# %%
df['Status_num']=df['Status'].map({'Active':1,'Inactive':0})

# %%
df.head()
# Out:
#    User_ID    Name              Email      Phone        City  Age    Status  \
# 0        1  User_1  user1@example.com  170000001       Dhaka   19    Active
# 1        2  User_2  user2@example.com  170000002  Chattogram   20  Inactive
# 2        3  User_3  user3@example.com  170000003      Khulna   21    Active
# 3        4  User_4  user4@example.com  170000004    Rajshahi   22  Inactive
# 4        5  User_5  user5@example.com  170000005      Sylhet   23    Active
#
#    Status_num
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1

# %%
df[df['Name']=='User_3']
# Out:
#    User_ID    Name              Email      Phone    City  Age  Status  \
# 2        3  User_3  user3@example.com  170000003  Khulna   21  Active
#
#    Status_num
# 2           1

# %%
missing_column=df.isnull().sum()

# %%
missing_column
# Out:
# User_ID       0
# Name          0
# Email         0
# Phone         0
# City          0
# Age           0
# Status        0
# Status_num    0
# dtype: int64

# %%
df.shape
# Out:
# (50, 8)

# %%
df=df.dropna(subset=['Age'])

# %%
df.shape  # jeheto kono null value nai tai shape change hoi nai
# Out:
# (50, 8)

# %%
df=df.drop('Age',axis=1) #axis=1 mane column borabor search krbe;jodi kiso na dey mane axis=1 eta na lekhi by defult 0 dore nibe;axis=0 mane row borabor search krbe

# %%
df.shape
# Out:
# (50, 7)

# %%
df.head()
# Out:
#    User_ID    Name              Email      Phone        City    Status  \
# 0        1  User_1  user1@example.com  170000001       Dhaka    Active
# 1        2  User_2  user2@example.com  170000002  Chattogram  Inactive
# 2        3  User_3  user3@example.com  170000003      Khulna    Active
# 3        4  User_4  user4@example.com  170000004    Rajshahi  Inactive
# 4        5  User_5  user5@example.com  170000005      Sylhet    Active
#
#    Status_num
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1

# %%
df['User_ID'].mean()
# Out:
# np.float64(25.5)

# %%
df['User_ID']=df['User_ID'].fillna(df['User_ID'].mean())

# %%
df['User_ID'].mean()
# Out:
# np.float64(25.5)

# %%
df['User_ID']=df['User_ID'].fillna(df['User_ID'].median())

# %%
df['User_ID'].median()
# Out:
# 25.5

# %%
df.drop(2)
# Out:
#     User_ID     Name               Email      Phone        City    Status  \
# 0         1   User_1   user1@example.com  170000001       Dhaka    Active
# 1         2   User_2   user2@example.com  170000002  Chattogram  Inactive
# 3         4   User_4   user4@example.com  170000004    Rajshahi  Inactive
# 4         5   User_5   user5@example.com  170000005      Sylhet    Active
# 5         6   User_6   user6@example.com  170000006       Dhaka  Inactive
# 6         7   User_7   user7@example.com  170000007  Chattogram    Active
# 7         8   User_8   user8@example.com  170000008      Khulna  Inactive
# 8         9   User_9   user9@example.com  170000009    Rajshahi    Active
# 9        10  User_10  user10@example.com  170000010      Sylhet  Inactive
# 10       11  User_11  user11@example.com  170000011       Dhaka    Active
# 11       12  User_12  user12@example.com  170000012  Chattogram  Inactive
# 12       13  User_13  user13@example.com  170000013      Khulna    Active
# ...

# %%
df.head()
# Out:
#    User_ID    Name              Email      Phone        City    Status  \
# 0        1  User_1  user1@example.com  170000001       Dhaka    Active
# 1        2  User_2  user2@example.com  170000002  Chattogram  Inactive
# 2        3  User_3  user3@example.com  170000003      Khulna    Active
# 3        4  User_4  user4@example.com  170000004    Rajshahi  Inactive
# 4        5  User_5  user5@example.com  170000005      Sylhet    Active
#
#    Status_num
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1

# %%
df.drop(2)
# Out:
#     User_ID     Name               Email      Phone        City    Status  \
# 0         1   User_1   user1@example.com  170000001       Dhaka    Active
# 1         2   User_2   user2@example.com  170000002  Chattogram  Inactive
# 3         4   User_4   user4@example.com  170000004    Rajshahi  Inactive
# 4         5   User_5   user5@example.com  170000005      Sylhet    Active
# 5         6   User_6   user6@example.com  170000006       Dhaka  Inactive
# 6         7   User_7   user7@example.com  170000007  Chattogram    Active
# 7         8   User_8   user8@example.com  170000008      Khulna  Inactive
# 8         9   User_9   user9@example.com  170000009    Rajshahi    Active
# 9        10  User_10  user10@example.com  170000010      Sylhet  Inactive
# 10       11  User_11  user11@example.com  170000011       Dhaka    Active
# 11       12  User_12  user12@example.com  170000012  Chattogram  Inactive
# 12       13  User_13  user13@example.com  170000013      Khulna    Active
# ...

# %%
df.head()
# Out:
#    User_ID    Name              Email      Phone        City    Status  \
# 0        1  User_1  user1@example.com  170000001       Dhaka    Active
# 1        2  User_2  user2@example.com  170000002  Chattogram  Inactive
# 2        3  User_3  user3@example.com  170000003      Khulna    Active
# 3        4  User_4  user4@example.com  170000004    Rajshahi  Inactive
# 4        5  User_5  user5@example.com  170000005      Sylhet    Active
#
#    Status_num
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1

# %%
df=df.drop(2)

# %%
df.head()
# Out:
#    User_ID    Name              Email      Phone        City    Status  \
# 0        1  User_1  user1@example.com  170000001       Dhaka    Active
# 1        2  User_2  user2@example.com  170000002  Chattogram  Inactive
# 3        4  User_4  user4@example.com  170000004    Rajshahi  Inactive
# 4        5  User_5  user5@example.com  170000005      Sylhet    Active
# 5        6  User_6  user6@example.com  170000006       Dhaka  Inactive
#
#    Status_num
# 0           1
# 1           0
# 3           0
# 4           1
# 5           0

# %%
df
# Out:
#     User_ID     Name               Email      Phone        City    Status  \
# 0         1   User_1   user1@example.com  170000001       Dhaka    Active
# 1         2   User_2   user2@example.com  170000002  Chattogram  Inactive
# 3         4   User_4   user4@example.com  170000004    Rajshahi  Inactive
# 4         5   User_5   user5@example.com  170000005      Sylhet    Active
# 5         6   User_6   user6@example.com  170000006       Dhaka  Inactive
# 6         7   User_7   user7@example.com  170000007  Chattogram    Active
# 7         8   User_8   user8@example.com  170000008      Khulna  Inactive
# 8         9   User_9   user9@example.com  170000009    Rajshahi    Active
# 9        10  User_10  user10@example.com  170000010      Sylhet  Inactive
# 10       11  User_11  user11@example.com  170000011       Dhaka    Active
# 11       12  User_12  user12@example.com  170000012  Chattogram  Inactive
# 12       13  User_13  user13@example.com  170000013      Khulna    Active
# ...

# %%
df=df.drop('Phone',axis=1)

# %%
df.head()
# Out:
#    User_ID    Name              Email        City    Status  Status_num
# 0        1  User_1  user1@example.com       Dhaka    Active           1
# 1        2  User_2  user2@example.com  Chattogram  Inactive           0
# 3        4  User_4  user4@example.com    Rajshahi  Inactive           0
# 4        5  User_5  user5@example.com      Sylhet    Active           1
# 5        6  User_6  user6@example.com       Dhaka  Inactive           0

# %%
df=df.drop(5,axis=0)

# %%
df.head()
# Out:
#    User_ID    Name              Email        City    Status  Status_num
# 0        1  User_1  user1@example.com       Dhaka    Active           1
# 1        2  User_2  user2@example.com  Chattogram  Inactive           0
# 3        4  User_4  user4@example.com    Rajshahi  Inactive           0
# 4        5  User_5  user5@example.com      Sylhet    Active           1
# 6        7  User_7  user7@example.com  Chattogram    Active           1

# %%
# !git clone https://github.com/arnayeem2001/Machine-Learning.git
# Out:
# Cloning into 'Machine-Learning'...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/github_projects/pandas_project
# !ls /content/drive/MyDrive/github_projects
# Out:
# pandas_project

# %%
# !cp /content/drive/MyDrive/pandas_manipulation_12-01-23.ipynb \
/content/drive/MyDrive/github_projects/pandas_project/
# !ls /content/drive/MyDrive
# Out:
# cp: cannot stat '/content/drive/MyDrive/pandas_manipulation_12-01-23.ipynb': No such file or directory
# '16 Dec YBF'
#  231.jpg
# 'Audio from Abdur Rahman Nayeem'
# 'Colab Notebooks'
#  collection
# 'Copy of meeting section (Responses).gsheet'
# 'Copy of Privacy Policy_IntellixlabzAI.gdoc'
#  data
#  Diu
# 'Fizzar Sir'
#  github_projects
#  IBCC_3.jpg
# 'IBCCC Quiz 2 Sec C.pdf'
#  IBC-DIU
#  IMG-20230321-WA0000.jpg
#  Information.gform
# 'Information (Responses).gsheet'
#  Myself
#  nayeem.repo.PNG
# 'Privacy Policy_IntellixlabzAI.gdoc'
#  Pythron
#  Screenshot_2023-10-17-09-30-32-68_9a0991d06c39f5556bb727ecc6fd035e.jpg
# 'Spring 2024'
# 'Team roster.gsheet'
# 'Translated copy of Untitled document.gdoc'
#  Udvash
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form (1).gform'
# ...

# %%
# !ls /content/drive/MyDrive
# Out:
# '16 Dec YBF'
#  231.jpg
# 'Audio from Abdur Rahman Nayeem'
# 'Colab Notebooks'
#  collection
# 'Copy of meeting section (Responses).gsheet'
# 'Copy of Privacy Policy_IntellixlabzAI.gdoc'
#  data
#  Diu
# 'Fizzar Sir'
#  github_projects
#  IBCC_3.jpg
# 'IBCCC Quiz 2 Sec C.pdf'
#  IBC-DIU
#  IMG-20230321-WA0000.jpg
#  Information.gform
# 'Information (Responses).gsheet'
#  Myself
#  nayeem.repo.PNG
# 'Privacy Policy_IntellixlabzAI.gdoc'
#  Pythron
#  Screenshot_2023-10-17-09-30-32-68_9a0991d06c39f5556bb727ecc6fd035e.jpg
# 'Spring 2024'
# 'Team roster.gsheet'
# 'Translated copy of Untitled document.gdoc'
#  Udvash
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
#  voice
#  YBF
# ...

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# data_visualization_11_12_25.ipynb  Ostad_pandas_intro.ipynb
# ML_intro_4_12_25.ipynb		   pandas_manipulation_12-01-23.ipynb
# numpy-pandas_27_11_25.ipynb	   Untitled0.ipynb
# Ostad_numpy_intro.ipynb		   Untitled1.ipynb
